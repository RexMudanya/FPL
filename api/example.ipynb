# %%
from methods import FantasyPremier
import json
import pandas as pd

# %%
fpl = FantasyPremier()

# %%
data = fpl.get_general_information()

# %%
data.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
pd.DataFrame(data['elements']).head(5)
# Out:
#    chance_of_playing_next_round  chance_of_playing_this_round   code  \
# 0                           0.0                           0.0  37605
# 1                           0.0                           0.0  39476
# 2                          75.0                          75.0  41270
# 3                         100.0                         100.0  54694
# 4                         100.0                         100.0  58822
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                 -3
# 1                  0                       0                 -2
# 2                  0                       0                 -1
# 3                  0                       0                 -7
# 4                  0                       0                 -4
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                       3                0             3     0.0  ...
# ...

# %%
pd.DataFrame(data['elements']).columns
# Out:
# Index(['chance_of_playing_next_round', 'chance_of_playing_this_round', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'id', 'in_dreamteam',
#        'news', 'news_added', 'now_cost', 'photo', 'points_per_game',
#        'second_name', 'selected_by_percent', 'special', 'squad_number',
#        'status', 'team', 'team_code', 'total_points', 'transfers_in',
#        'transfers_in_event', 'transfers_out', 'transfers_out_event',
#        'value_form', 'value_season', 'web_name', 'minutes', 'goals_scored',
#        'assists', 'clean_sheets', 'goals_conceded', 'own_goals',
#        'penalties_saved', 'penalties_missed', 'yellow_cards', 'red_cards',
#        'saves', 'bonus', 'bps', 'influence', 'creativity', 'threat',
#        'ict_index', 'influence_rank', 'influence_rank_type', 'creativity_rank',
# ...

# %%
elements = pd.DataFrame(data['elements'])
elements['code'].head(5)
# Out:
# 0    37605
# 1    39476
# 2    41270
# 3    54694
# 4    58822
# Name: code, dtype: int64

# %%
data['elements'][301]
# Out:
# {'chance_of_playing_next_round': 100,
#  'chance_of_playing_this_round': 100,
#  'code': 228798,
#  'cost_change_event': 0,
#  'cost_change_event_fall': 0,
#  'cost_change_start': -3,
#  'cost_change_start_fall': 3,
#  'dreamteam_count': 0,
#  'element_type': 3,
#  'ep_next': '0.0',
#  'ep_this': '1.0',
#  'event_points': 0,
#  'first_name': 'Cengiz',
#  'form': '0.0',
#  'id': 541,
#  'in_dreamteam': False,
#  'news': '',
#  'news_added': '2021-03-08T08:30:22.097958Z',
#  'now_cost': 57,
#  'photo': '228798.jpg',
#  'points_per_game': '1.8',
#  'second_name': 'Ünder',
#  'selected_by_percent': '0.0',
#  'special': False,
#  'squad_number': None,
#  'status': 'a',
#  'team': 9,
#  'team_code': 13,
#  'total_points': 16,
#  'transfers_in': 15241,
#  'transfers_in_event': 1,
#  'transfers_out': 15436,
#  'transfers_out_event': 3,
#  'value_form': '0.0',
#  'value_season': '2.8',
#  'web_name': 'Ünder',
#  'minutes': 275,
#  'goals_scored': 0,
#  'assists': 2,
#  'clean_sheets': 0,
# ...

# %%
pd.DataFrame(data['teams']).head(5)
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    36     0  None   3     0     Brighton       0       0         0
# 3    90     0  None   4     0      Burnley       0       0         0
# 4     8     0  None   5     0      Chelsea       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1200
# 1        AVL  ...           None       False    0                   1100
# 2        BHA  ...           None       False    0                   1130
# 3        BUR  ...           None       False    0                   1060
# 4        CHE  ...           None       False    0                   1250
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# ...

# %%
pd.DataFrame(data['events']).head(5)
# Out:
#    id        name         deadline_time  average_entry_score  finished  \
# 0   1  Gameweek 1  2020-09-12T10:00:00Z                   50      True
# 1   2  Gameweek 2  2020-09-19T10:00:00Z                   59      True
# 2   3  Gameweek 3  2020-09-26T10:00:00Z                   43      True
# 3   4  Gameweek 4  2020-10-03T10:00:00Z                   48      True
# 4   5  Gameweek 5  2020-10-17T10:00:00Z                   60      True
#
#    data_checked  highest_scoring_entry  deadline_time_epoch  \
# 0          True              4761681.0           1599904800
# 1          True              6234344.0           1600509600
# 2          True              6223553.0           1601114400
# 3          True              6563000.0           1601719200
# 4          True              7124486.0           1602928800
#
#    deadline_time_game_offset  highest_score  ...  is_current  is_next  \
# 0                          0          142.0  ...       False    False
# ...

# %%
pd.DataFrame(data['element_stats'])
# Out:
#                   label              name
# 0        Minutes played           minutes
# 1          Goals scored      goals_scored
# 2               Assists           assists
# 3          Clean sheets      clean_sheets
# 4        Goals conceded    goals_conceded
# 5             Own goals         own_goals
# 6       Penalties saved   penalties_saved
# 7      Penalties missed  penalties_missed
# 8          Yellow cards      yellow_cards
# 9             Red cards         red_cards
# 10                Saves             saves
# 11                Bonus             bonus
# 12  Bonus Points System               bps
# 13            Influence         influence
# 14           Creativity        creativity
# 15               Threat            threat
# 16            ICT Index         ict_index

# %%
from player import Player

# %%
pl = Player()

# %%
all_data = pl.get_all_data(302)

# %%
all_data.keys()
# Out:
# dict_keys(['fixtures', 'history', 'history_past'])

# %%
pd.DataFrame(all_data['history']).head(5)
# Out:
#    element  fixture  opponent_team  total_points  was_home  \
# 0      302       15              6             2      True
# 1      302       19              3            12     False
# 2      302       35             17             6      True
# 3      302       45             14            11     False
# 4      302       55              5             3      True
#
#            kickoff_time  team_h_score  team_a_score  round  minutes  ...  bps  \
# 0  2020-09-19T16:30:00Z           1.0           3.0      2       90  ...   13
# 1  2020-09-26T11:30:00Z           2.0           3.0      3       90  ...   40
# 2  2020-10-04T15:30:00Z           1.0           6.0      4       45  ...   21
# 3  2020-10-17T19:00:00Z           1.0           4.0      5       90  ...   49
# 4  2020-10-24T16:30:00Z           0.0           0.0      6       90  ...   14
#
#    influence  creativity  threat  ict_index  value  transfers_balance  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
pd.DataFrame(all_data['history']).columns
# Out:
# Index(['element', 'fixture', 'opponent_team', 'total_points', 'was_home',
#        'kickoff_time', 'team_h_score', 'team_a_score', 'round', 'minutes',
#        'goals_scored', 'assists', 'clean_sheets', 'goals_conceded',
#        'own_goals', 'penalties_saved', 'penalties_missed', 'yellow_cards',
#        'red_cards', 'saves', 'bonus', 'bps', 'influence', 'creativity',
#        'threat', 'ict_index', 'value', 'transfers_balance', 'selected',
#        'transfers_in', 'transfers_out'],
#       dtype='object')

# %%
d = pd.DataFrame(all_data['history'])
plt.plot(d['total_points'], label='points')
plt.plot(d['bonus'], label='bonus')
plt.legend()
plt.title('points + bonus per GW')
plt.ylabel('points')
plt.xlabel('gw')
plt.show()

# %%
plt.plot(d['value'])
plt.title('value per GW')
plt.ylabel('value')
plt.xlabel('gw')
plt.show()

# %%
plt.plot(d['transfers_in'], label='in')
plt.plot(d['transfers_out'], label='out')
plt.title('transfers in vs out')
plt.legend()
plt.ylabel('transfers')
plt.xlabel('gw')
plt.show()

# %%
plt.plot(d['goals_scored'], label='goals')
plt.plot(d['assists'], label='assists')
plt.title('goals and assists')
plt.legend()
plt.ylabel('goals + assists')
plt.xlabel('gw')
plt.show()

# %%
fixtures = pl.get_fixtures(302)

# %%
fixtures
# Out:
# [{'id': 340,
#   'code': 2128627,
#   'team_h': 2,
#   'team_h_score': None,
#   'team_a': 13,
#   'team_a_score': None,
#   'event': 35,
#   'finished': False,
#   'minutes': 0,
#   'provisional_start_time': False,
#   'kickoff_time': '2021-05-09T13:05:00Z',
#   'event_name': 'Gameweek 35',
#   'is_home': False,
#   'difficulty': 3},
#  {'id': 352,
#   'code': 2128639,
#   'team_h': 13,
#   'team_h_score': None,
#   'team_a': 9,
#   'team_a_score': None,
#   'event': 35,
#   'finished': False,
#   'minutes': 0,
#   'provisional_start_time': False,
#   'kickoff_time': '2021-05-11T17:00:00Z',
#   'event_name': 'Gameweek 35',
#   'is_home': True,
#   'difficulty': 4},
#  {'id': 334,
#   'code': 2128621,
#   'team_h': 13,
#   'team_h_score': None,
#   'team_a': 11,
#   'team_a_score': None,
#   'event': 35,
#   'finished': False,
#   'minutes': 0,
#   'provisional_start_time': False,
#   'kickoff_time': '2021-05-13T19:15:00Z',
#   'event_name': 'Gameweek 35',
#   'is_home': True,
# ...

# %%
type(fixtures)
# Out:
# list

# %%
x = 0
for i in fixtures:
    x += 1
print(x)
# Out:
# 5

# %%
for item in fixtures[0].keys():
    print(item)
# Out:
# id
# code
# team_h
# team_h_score
# team_a
# team_a_score
# event
# finished
# minutes
# provisional_start_time
# kickoff_time
# event_name
# is_home
# difficulty

# %%
past_hist = pl.get_past_history(302)

# %%
type(past_hist)
# Out:
# list

# %%
past_hist
# Out:
# [{'season_name': '2019/20',
#   'element_code': 141746,
#   'start_cost': 80,
#   'end_cost': 90,
#   'total_points': 117,
#   'minutes': 1187,
#   'goals_scored': 8,
#   'assists': 8,
#   'clean_sheets': 9,
#   'goals_conceded': 6,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 18,
#   'bps': 366,
#   'influence': '551.8',
#   'creativity': '479.3',
#   'threat': '361.0',
#   'ict_index': '139.2'}]

# %%
for item in past_hist[0].keys():
    print(item)
# Out:
# season_name
# element_code
# start_cost
# end_cost
# total_points
# minutes
# goals_scored
# assists
# clean_sheets
# goals_conceded
# own_goals
# penalties_saved
# penalties_missed
# yellow_cards
# red_cards
# saves
# bonus
# bps
# influence
# creativity
# threat
# ict_index
